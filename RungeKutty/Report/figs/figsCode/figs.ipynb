# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set(rc = {"figure.figsize":(16, 9)})

# %%
points = np.array([1., 1.010050, 1.020201, 1.030455, 1.040811, 1.051271, 1.061837, 1.072508, 1.083287, 1.094174, 1.105171, 1.116278, 1.127497, 1.138828, 1.150274, 1.161834, 1.173511, 1.185305, 1.197217, 1.209250, 1.221403, 1.233678, 1.246077, 1.258600, 1.271249, 1.284025, 1.296930, 1.309964, 1.323130, 1.336427, 1.349859, 1.363425, 1.377128, 1.390968, 1.404948, 1.419068, 1.433329, 1.447735, 1.462285, 1.476981, 1.491825, 1.506818, 1.521962, 1.537258, 1.552707, 1.568312, 1.584074, 1.599994, 1.616074, 1.632316, 1.648721, 1.665291, 1.682028, 1.698932, 1.716007, 1.733253, 1.750673, 1.768267, 1.786038, 1.803988, 1.822119, 1.840431, 1.858928, 1.877611, 1.896481, 1.915541, 1.934792, 1.954237, 1.973878, 1.993716, 2.013753, 2.033991, 2.054433, 2.075081, 2.095936, 2.117000, 2.138276, 2.159766, 2.181472, 2.203396, 2.225541, 2.247908, 2.270500, 2.293319, 2.316367, 2.339647, 2.363161, 2.386911, 2.410900, 2.435130, 2.459603, 2.484323, 2.509290, 2.534509, 2.559981, 2.585710, 2.611696, 2.637944, 2.664456, 2.691234, 2.718282])

# %%
plt.plot(np.arange(0., 1.01, 0.01), points, label=r"Численная траектория $y$")
plt.plot(np.arange(0., 1.011, 0.01), np.exp(np.arange(0., 1.011, 0.01)), label=r"Точное решение ($y(x) = e^x$)")
plt.title(r"Уравнение: $y'=y$, $y(0) = 1$, $h=0.01$, $x \in [0, 1]$")
plt.legend()
plt.savefig("../Test1.pdf")

# %%
points2 = np.array([1.0, 1.000050, 1.000200, 1.000450, 1.000800, 1.001250, 1.001800, 1.002450, 1.003200, 1.004050, 1.005000, 1.006050, 1.007200, 1.008450, 1.009800, 1.011250, 1.012800, 1.014450, 1.016200, 1.018050, 1.020000, 1.022050, 1.024200, 1.026450, 1.028800, 1.031250, 1.033800, 1.036450, 1.039200, 1.042050, 1.045000, 1.048050, 1.051200, 1.054450, 1.057800, 1.061250, 1.064800, 1.068450, 1.072200, 1.076050, 1.080000, 1.084050, 1.088200, 1.092450, 1.096800, 1.101250, 1.105800, 1.110450, 1.115200, 1.120050, 1.125000, 1.130050, 1.135200, 1.140450, 1.145800, 1.151250, 1.156800, 1.162450, 1.168200, 1.174050, 1.180000, 1.186050, 1.192200, 1.198450, 1.204800, 1.211250, 1.217800, 1.224450, 1.231200, 1.238050, 1.245000, 1.252050, 1.259200, 1.266450, 1.273800, 1.281250, 1.288800, 1.296450, 1.304200, 1.312050, 1.320000, 1.328050, 1.336200, 1.344450, 1.352800, 1.361250, 1.369800, 1.378450, 1.387200, 1.396050, 1.405000, 1.414050, 1.423200, 1.432450, 1.441800, 1.451250, 1.460800, 1.470450, 1.480200, 1.490050, 1.500000])

# %%
plt.plot(np.arange(0., 1.01, 0.01), points2, label=r"Численная траектория $y$")
plt.plot(np.arange(0., 1.0, 0.01), 1 + 0.5 * np.arange(0., 1.0, 0.01) * np.arange(0., 1.0, 0.01), label=r"Точное решение ($y(x) = 1 + \frac{1}{2} x^2$)")
plt.title(r"Уравнение: $y'=x$, $y(0) = 1$, $h=0.01$, $x \in [0, 1]$")
plt.legend()
plt.savefig("../Test2.pdf")

# %%
points3 = np.array([1, -1, 0.990050, -0.990050, 0.980199, -0.980199, 0.970446, -0.970446, 0.960789, -0.960789, 0.951229, -0.951229, 0.941765, -0.941765, 0.932394, -0.932394, 0.923116, -0.923116, 0.913931, -0.913931, 0.904837, -0.904837, 0.895834, -0.895834, 0.886920, -0.886920, 0.878095, -0.878095, 0.869358, -0.869358, 0.860708, -0.860708, 0.852144, -0.852144, 0.843665, -0.843665, 0.835270, -0.835270, 0.826959, -0.826959, 0.818731, -0.818731, 0.810584, -0.810584, 0.802519, -0.802519, 0.794534, -0.794534, 0.786628, -0.786628, 0.778801, -0.778801, 0.771052, -0.771052, 0.763379, -0.763379, 0.755784, -0.755784, 0.748264, -0.748264, 0.740818, -0.740818, 0.733447, -0.733447, 0.726149, -0.726149, 0.718924, -0.718924, 0.711770, -0.711770, 0.704688, -0.704688, 0.697676, -0.697676, 0.690734, -0.690734, 0.683861, -0.683861, 0.677057, -0.677057, 0.670320, -0.670320, 0.663650, -0.663650, 0.657047, -0.657047, 0.650509, -0.650509, 0.644036, -0.644036, 0.637628, -0.637628, 0.631284, -0.631284, 0.625002, -0.625002, 0.618783, -0.618783, 0.612626, -0.612626, 0.606531, -0.606531, 0.600496, -0.600496, 0.594521, -0.594521, 0.588605, -0.588605, 0.582748, -0.582748, 0.576950, -0.576950, 0.571209, -0.571209, 0.565525, -0.565525, 0.559898, -0.559898, 0.554327, -0.554327, 0.548812, -0.548812, 0.543351, -0.543351, 0.537944, -0.537944, 0.532592, -0.532592, 0.527292, -0.527292, 0.522046, -0.522046, 0.516851, -0.516851, 0.511709, -0.511709, 0.506617, -0.506617, 0.501576, -0.501576, 0.496585, -0.496585, 0.491644, -0.491644, 0.486752, -0.486752, 0.481909, -0.481909, 0.477114, -0.477114, 0.472367, -0.472367, 0.467666, -0.467666, 0.463013, -0.463013, 0.458406, -0.458406, 0.453845, -0.453845, 0.449329, -0.449329, 0.444858, -0.444858, 0.440432, -0.440432, 0.436049, -0.436049, 0.431710, -0.431711, 0.427415, -0.427415, 0.423162, -0.423162, 0.418952, -0.418952, 0.414783, -0.414783, 0.410656, -0.410656, 0.406570, -0.406570, 0.402524, -0.402524, 0.398519, -0.398519, 0.394554, -0.394554, 0.390628, -0.390628, 0.386741, -0.386741, 0.382893, -0.382893, 0.379083, -0.379083, 0.375311, -0.375311, 0.371577, -0.371577])

# %%
x = np.arange(0., 1.0, 0.01)

plt.plot(x, points3[::2], label=r"Численная траектория $y_1$")
plt.plot(x, points3[1::2], label=r"Численное траектория $y_2$")
plt.plot(x, np.exp(-x), label=r"Точное решение: $y_1 = e^{-x}$")
plt.plot(x, -np.exp(-x), label=r"Точное решение: $y_2 = - e^{-x}$")
# plt.plot(np.arange(0., 1.0, 0.01), 1 + 0.5 * np.arange(0., 1.0, 0.01) * np.arange(0., 1.0, 0.01), label=r"Точное решение ($y(x) = 1 + \frac{1}{2} x^2$)")
plt.title(r"Система $y_1'=y_2$, $y_2'=y_1$, $y_1(0) = 1$, $y_2(0) = -1$, $h=0.01$, $x \in [0, 1]$")
plt.legend()
plt.savefig("../Test3.pdf")

# %%
points4 = np.array([1, -1, 1.000000, -0.999899, 1.000000, -0.999592, 1.000001, -0.999073, 1.000003, -0.998336, 1.000006, -0.997375, 1.000013, -0.996184, 1.000024, -0.994757, 1.000041, -0.993088, 1.000066, -0.991171, 1.000100, -0.989000, 1.000146, -0.986569, 1.000207, -0.983872, 1.000286, -0.980903, 1.000384, -0.977656, 1.000506, -0.974125, 1.000655, -0.970304, 1.000835, -0.966187, 1.001050, -0.961768, 1.001303, -0.957041, 1.001600, -0.952000, 1.001945, -0.946639, 1.002343, -0.940952, 1.002798, -0.934933, 1.003318, -0.928576, 1.003906, -0.921875, 1.004570, -0.914824, 1.005314, -0.907417, 1.006147, -0.899648, 1.007073, -0.891511, 1.008100, -0.883000, 1.009235, -0.874109, 1.010486, -0.864832, 1.011859, -0.855163, 1.013363, -0.845096, 1.015006, -0.834625, 1.016796, -0.823744, 1.018742, -0.812447, 1.020851, -0.800728, 1.023134, -0.788581, 1.025600, -0.776000, 1.028258, -0.762979, 1.031117, -0.749512, 1.034188, -0.735593, 1.037481, -0.721216, 1.041006, -0.706375, 1.044775, -0.691064, 1.048797, -0.675277, 1.053084, -0.659008, 1.057648, -0.642251, 1.062500, -0.625000, 1.067652, -0.607249, 1.073116, -0.588992, 1.078905, -0.570223, 1.085031, -0.550936, 1.091506, -0.531125, 1.098345, -0.510784, 1.105560, -0.489907, 1.113165, -0.468488, 1.121174, -0.446521, 1.129600, -0.424000, 1.138458, -0.400919, 1.147763, -0.377272, 1.157530, -0.353053, 1.167772, -0.328256, 1.178506, -0.302875, 1.189747, -0.276904, 1.201511, -0.250337, 1.213814, -0.223168, 1.226671, -0.195391, 1.240100, -0.167000, 1.254117, -0.137989, 1.268739, -0.108352, 1.283982, -0.078083, 1.299866, -0.047176, 1.316406, -0.015625, 1.333622, 0.016576, 1.351530, 0.049433, 1.370151, 0.082952, 1.389501, 0.117139, 1.409600, 0.152000, 1.430467, 0.187541, 1.452122, 0.223768, 1.474583, 0.260687, 1.497871, 0.298304, 1.522006, 0.336625, 1.547008, 0.375656, 1.572898, 0.415403, 1.599695, 0.455872, 1.627422, 0.497069, 1.656100, 0.539000, 1.685750, 0.581671, 1.716393, 0.625088, 1.748052, 0.669257, 1.780749, 0.714184, 1.814506, 0.759875, 1.849347, 0.806336, 1.885293, 0.853573, 1.922368, 0.901592, 1.960596, 0.950399])

# %%
x = np.arange(0., 1.0, 0.01)

plt.plot(x, points4[::2], label=r"Численная траектория $y_1$")
plt.plot(x, points4[1::2], label=r"Численное траектория $y_2$")
plt.plot(x, x**4 + 1, label=r"Точное решение: $y_1 = x^4 + 1$")
plt.plot(x, x**3 + x**2 - 1, label=r"Точное решение: $y_2 = x^3 + x^2 - 1$")
# plt.plot(np.arange(0., 1.0, 0.01), 1 + 0.5 * np.arange(0., 1.0, 0.01) * np.arange(0., 1.0, 0.01), label=r"Точное решение ($y(x) = 1 + \frac{1}{2} x^2$)")
plt.title(r"Система $y_1'=4 x^3$, $y_2'=3x^2 + 2x$, $y_1(0) = 1$, $y_2(0) = -1$, $h=0.01$, $x \in [0, 1]$")
plt.legend()
plt.savefig("../Test4.pdf")

# %%
points5 = np.array([1., -1, 1.000000, -0.999899, 1.000000, -0.999592, 1.000000, -0.999073, 1.000000, -0.998336, 1.000000, -0.997375, 1.000001, -0.996184, 1.000002, -0.994757, 1.000003, -0.993088, 1.000006, -0.991171, 1.000010, -0.989000, 1.000016, -0.986569, 1.000025, -0.983872, 1.000037, -0.980903, 1.000054, -0.977656, 1.000076, -0.974125, 1.000105, -0.970304, 1.000142, -0.966187, 1.000189, -0.961768, 1.000248, -0.957041, 1.000320, -0.952000, 1.000408, -0.946639, 1.000515, -0.940952, 1.000644, -0.934933, 1.000796, -0.928576, 1.000977, -0.921875, 1.001188, -0.914824, 1.001435, -0.907417, 1.001721, -0.899648, 1.002051, -0.891511, 1.002430, -0.883000, 1.002863, -0.874109, 1.003355, -0.864832, 1.003914, -0.855163, 1.004544, -0.845096, 1.005252, -0.834625, 1.006047, -0.823744, 1.006934, -0.812447, 1.007924, -0.800728, 1.009022, -0.788581, 1.010240, -0.776000, 1.011586, -0.762979, 1.013069, -0.749512, 1.014701, -0.735593, 1.016492, -0.721216, 1.018453, -0.706375, 1.020596, -0.691064, 1.022935, -0.675277, 1.025480, -0.659008, 1.028248, -0.642251, 1.031250, -0.625000, 1.034503, -0.607249, 1.038020, -0.588992, 1.041820, -0.570223, 1.045917, -0.550936, 1.050328, -0.531125, 1.055073, -0.510784, 1.060169, -0.489907, 1.065636, -0.468488, 1.071492, -0.446521, 1.077760, -0.424000, 1.084460, -0.400919, 1.091613, -0.377272, 1.099244, -0.353053, 1.107374, -0.328256, 1.116029, -0.302875, 1.125233, -0.276904, 1.135013, -0.250337, 1.145393, -0.223168, 1.156403, -0.195391, 1.168070, -0.167000, 1.180423, -0.137989, 1.193492, -0.108352, 1.207307, -0.078083, 1.221901, -0.047176, 1.237305, -0.015625, 1.253553, 0.016576, 1.270678, 0.049433, 1.288717, 0.082952, 1.307706, 0.117139, 1.327680, 0.152000, 1.348678, 0.187541, 1.370740, 0.223768, 1.393904, 0.260687, 1.418212, 0.298304, 1.443705, 0.336625, 1.470427, 0.375656, 1.498421, 0.415403, 1.527732, 0.455872, 1.558406, 0.497069, 1.590490, 0.539000, 1.624032, 0.581671, 1.659082, 0.625088, 1.695688, 0.669257, 1.733904, 0.714184, 1.773781, 0.759875, 1.815373, 0.806336, 1.858734, 0.853573, 1.903921, 0.901592, 1.950990, 0.950399])

# %%
x = np.arange(0., 1.0, 0.01)

plt.plot(x, points5[::2], label=r"Численная траектория $y_1$")
plt.plot(x, points5[1::2], label=r"Численное траектория $y_2$")
plt.plot(x, x**5 + 1, label=r"Точное решение: $y_1 = x^5 + 1$")
plt.plot(x, x**3 + x**2 - 1, label=r"Точное решение: $y_2 = x^3 + x^2 - 1$")
# plt.plot(np.arange(0., 1.0, 0.01), 1 + 0.5 * np.arange(0., 1.0, 0.01) * np.arange(0., 1.0, 0.01), label=r"Точное решение ($y(x) = 1 + \frac{1}{2} x^2$)")
plt.title(r"Система $y_1'=5 x^4$, $y_2'=3x^2 + 2x$, $y_1(0) = 1$, $y_2(0) = -1$, $h=0.01$, $x \in [0, 1]$")
plt.legend()
plt.savefig("../Test5.pdf")
